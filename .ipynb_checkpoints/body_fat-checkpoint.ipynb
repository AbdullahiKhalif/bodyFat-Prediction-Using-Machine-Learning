# %% [markdown]
# # BODY FAT PREDICTION

# %% [markdown]
# ### Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import dump
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis  # No direct regression counterpart
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# --------------------

# %% [markdown]
# # Reading External dataset

# %%
our_data = pd.read_csv('dataset/BodyFat - Extended.csv')

# %%
our_data.head()
# Out:
#    BodyFat Original Sex  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     12.3        Y   M   23   69.97    1.72  36.2   93.1     85.2   94.5
# 1      6.1        Y   M   22   78.59    1.84  38.5   93.6     83.0   98.7
# 2     25.3        Y   M   22   69.85    1.68  34.0   95.8     87.9   99.2
# 3     10.4        Y   M   26   83.80    1.84  37.4  101.8     86.4  101.2
# 4     28.7        Y   M   24   83.58    1.81  34.4   97.3    100.0  101.9
#
#    Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0   59.0  37.3   21.9    32.0     27.4   17.1
# 1   58.7  37.3   23.4    30.5     28.9   18.2
# 2   59.6  38.9   24.0    28.8     25.2   16.6
# 3   60.1  37.3   22.8    32.4     29.4   18.2
# 4   63.2  42.2   24.0    32.2     27.7   17.7

# %%
our_data.shape
# Out:
# (436, 16)

# %%
our_data.describe()
# Out:
#           BodyFat         Age      Weight      Height        Neck       Chest  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean    20.249839   34.545872   72.282203    1.734048   35.250917   94.158028
# std      7.502125   15.500099   15.464366    0.098359    3.837908   10.931688
# min      0.000000    1.000000   42.184800    0.750000   26.000000   43.000000
# 25%     15.022500   21.000000   59.875200    1.668780   31.500000   85.500000
# 50%     20.500000   28.500000   70.815800    1.730000   35.450000   93.050000
# 75%     25.410000   46.000000   81.560000    1.800000   38.300000  101.425000
# max     47.500000   81.000000  164.720000    1.970000   51.200000  136.200000
#
#           Abdomen         Hip       Thigh        Knee       Ankle      Biceps  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean    82.816055   98.652294   56.039679   37.365596   22.351835   29.897248
# std     14.652729    6.895034    6.194143    2.768403    1.780513    3.944843
# min     58.000000   82.500000   38.000000   24.700000   18.000000   20.500000
# 25%     70.000000   94.000000   51.500000   35.400000   21.000000   26.950000
# 50%     82.850000   98.300000   56.000000   37.500000   22.300000   29.800000
# 75%     93.225000  102.500000   60.000000   39.000000   23.300000   32.625000
# max    148.100000  147.700000   87.300000   49.100000   33.900000   45.000000
#
#           Forearm       Wrist
# count  436.000000  436.000000
# mean    26.482110   17.139908
# std      3.155306    1.582291
# min     20.000000   13.500000
# 25%     23.700000   16.000000
# 50%     26.650000   17.300000
# 75%     29.200000   18.400000
# max     34.900000   21.400000

# %% [markdown]
# ---------------------

# %% [markdown]
# # Statistics for categorical variables

# %%
categorical_stats = our_data.describe(include='O')  # 'O' stands for object (categorical)
print(categorical_stats)
# Out:
#        Original  Sex
# count       436  436
# unique        2    2
# top           Y    M
# freq        252  252

# %% [markdown]
# -----

# %%
our_data.columns
# Out:
# Index(['BodyFat', 'Original', 'Sex', 'Age', 'Weight', 'Height', 'Neck',
#        'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps',
#        'Forearm', 'Wrist'],
#       dtype='object')

# %% [markdown]
# -----------------

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### Checking any records in the dataset with (missing values, duplicates, etc) and hadling them.

# %%
# Check how many missing values in the dataset
print("The total missing values in this dataset:- " , len(our_data[our_data.isnull().any(axis=1)]))
# Out:
# The total missing values in this dataset:-  0

# %%
# Check how many duplicate values in the dataset
print("The total duplicate values in this dataset:- " , our_data.duplicated().sum())
# Out:
# The total duplicate values in this dataset:-  0

# %%
# Handling duplicate values if exists
# Dropping all duplicate values from the dataset permanently
df_unique = our_data.drop_duplicates()

# %% [markdown]
# -------------------------------

# %% [markdown]
# ## Checking outliers

# %%
# Define a function to detect outliers based on the IQR method
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return our_data[(our_data[column] < lower_bound) | (our_data[column] > upper_bound)].shape[0]

# Columns to check for outliers
columns_to_check =our_data.select_dtypes(include=[np.number])

# Calculate the number of outliers in each column
outliers_count = {column: detect_outliers_iqr(our_data, column) for column in columns_to_check}
outliers_count
# Out:
# {'BodyFat': 1,
#  'Age': 0,
#  'Weight': 2,
#  'Height': 1,
#  'Neck': 1,
#  'Chest': 4,
#  'Abdomen': 1,
#  'Hip': 4,
#  'Thigh': 4,
#  'Knee': 4,
#  'Ankle': 4,
#  'Biceps': 1,
#  'Forearm': 0,
#  'Wrist': 0}

# %% [markdown]
# --------------------

# %% [markdown]
# ## Dropping All Outliers from our dataset

# %%
# Define a function to remove outliers based on the IQR method for a given column
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(our_data[column] >= lower_bound) & (our_data[column] <= upper_bound)]

# Apply the outlier removal for each column individually
our_data = our_data.copy()
for column in columns_to_check:
    our_data = remove_outliers_iqr(our_data, column)

# Check the new shape of the dataset to see how many records remain
our_data.shape
# Out:
# (420, 16)

# %% [markdown]
# ---------

# %% [markdown]
# ## Encode categorical variables (Original & Sex) into numeric

# %%
our_data['Original'] = our_data['Original'].map({'Y': 1, 'N': 0})
our_data['Sex'] = our_data['Sex'].map({'M': 1, 'F': 0})

our_data
# Out:
#      BodyFat  Original  Sex  Age   Weight  Height  Neck  Chest  Abdomen  \
# 0      12.30         1    1   23  69.9700  1.7200  36.2   93.1     85.2
# 1       6.10         1    1   22  78.5900  1.8400  38.5   93.6     83.0
# 2      25.30         1    1   22  69.8500  1.6800  34.0   95.8     87.9
# 3      10.40         1    1   26  83.8000  1.8400  37.4  101.8     86.4
# 4      28.70         1    1   24  83.5800  1.8100  34.4   97.3    100.0
# ..       ...       ...  ...  ...      ...     ...   ...    ...      ...
# 431    30.40         0    0   23  59.8752  1.5621  31.3   89.0     71.0
# 432     7.47         0    0   21  48.5352  1.5748  29.5   79.0     62.5
# 433    11.98         0    0   20  51.7104  1.5748  31.5   81.5     61.5
# 434    11.24         0    0   22  50.8032  1.6510  30.5   85.0     64.0
# 435    17.49         0    0   24  47.6280  1.6002  26.0   79.3     63.0
#
#        Hip  Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     94.5   59.0  37.3   21.9    32.0     27.4   17.1
# 1     98.7   58.7  37.3   23.4    30.5     28.9   18.2
# 2     99.2   59.6  38.9   24.0    28.8     25.2   16.6
# 3    101.2   60.1  37.3   22.8    32.4     29.4   18.2
# 4    101.9   63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...    ...   ...    ...     ...      ...    ...
# 431   98.5   56.0  36.2   21.0    28.0     24.5   16.3
# 432   89.0   49.0  33.0   20.0    25.0     22.0   15.5
# 433   90.0   49.5  32.0   19.5    27.5     22.5   15.0
# 434   88.0   45.0  32.0   19.5    24.0     21.5   15.0
# 435   86.6   46.0  33.5   19.0    24.0     21.5   14.0
#
# [420 rows x 16 columns]

# %% [markdown]
# ---------------

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Displing all numerical varaibles

# %%
numeric_vars =['BodyFat', 'Age', 'Weight', 'Height', 'Neck',
       'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps',
       'Forearm', 'Wrist']

fig, axes = plt.subplots(len(numeric_vars), 1, figsize=(8, 3*len(numeric_vars)))  # Increase figsize

for i, predictor in enumerate(numeric_vars):
    sns.histplot(data=our_data, x=predictor, discrete=True, ax=axes[i])
    axes[i].set_title(predictor)

plt.tight_layout()
plt.show()
plt.close()

# %% [markdown]
# -----------

# %% [markdown]
# # Visualize Correlation of numerical variables

# %%
# Select only numeric columns
numeric_columns = our_data.select_dtypes(include=[np.number])

# Plot correlation heatmap for numeric columns
plt.figure(figsize=(10, 5))
sns.heatmap(numeric_columns.corr(), annot=True)
plt.show()

# %% [markdown]
# ----------------

# %% [markdown]
# ## Visualization Categorical variables using matplotlib (Pie chart)

# %%
# List of categorical variables for visualization, excluding Hypertension and Diabetes
categorical_vars = our_data[['Sex', 'Original']]
plt.figure(figsize=(20, 10))

for i, col in enumerate(categorical_vars):
    plt.subplot(1, 3, i + 1)

    x = our_data[col].value_counts()
    plt.pie(x.values,
            labels=x.index,
            autopct='%1.1f%%')
    plt.title(col)

    plt.gca().set_aspect('equal')  # Ensure pie charts are circular

# Remove the unused subplot
plt.subplot(1, 3, 3).remove()


plt.show()

# %% [markdown]
# ----------------------

# %% [markdown]
# # Building Models

# %% [markdown]
# ### Splitting features and target

# %%
# Splitting features and target
X = our_data.drop('BodyFat', axis=1)  # Features excluding 'BodyFat'
y = our_data['BodyFat']  # Target variable, 'BodyFat'

# %% [markdown]
# ## Splitting the data into training and testing sets (70% train, 30% test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ##  Define a list of regression models to test

# %%
# Define a list of regression models to test
regression_models = [
    KNeighborsRegressor(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    GradientBoostingRegressor(),
    AdaBoostRegressor(),
    LinearRegression(),
    SVR(), 
    Ridge(), 
    Lasso()
]

# %%
accuracy_train = {}

for reg_model in regression_models:
    reg_model.fit(X_train, y_train)
    y_pred_train = reg_model.predict(X_train)
    y_pred_test = reg_model.predict(X_test)
    
    accuracy_train[reg_model.__class__.__name__] = reg_model.score(X_train, y_train)
    accuracy_test = reg_model.score(X_test, y_test)
    
    # Calculating evaluation metrics
    mse = mean_squared_error(y_test, y_pred_test)
    mae = mean_absolute_error(y_test, y_pred_test)
    
    print(f" {reg_model.__class__.__name__} evaluation: ".center(100, "#"))
    print(f"Accuracy:\n Training: {accuracy_train[reg_model.__class__.__name__]:.3f}\n Testing: {accuracy_test:.3f}")
    print(f"Mean Squared Error: {mse:.3f}")
    print(f"Mean Absolute Error: {mae:.3f}")
    print()
# Out:
# ################################# KNeighborsRegressor evaluation: ##################################
# Accuracy:
#  Training: 0.692
#  Testing: 0.569
# Mean Squared Error: 24.932
# Mean Absolute Error: 3.905
#
# ################################ DecisionTreeRegressor evaluation: #################################
# Accuracy:
#  Training: 1.000
#  Testing: 0.333
# Mean Squared Error: 38.590
# Mean Absolute Error: 4.889
#
# ################################ RandomForestRegressor evaluation: #################################
# Accuracy:
#  Training: 0.941
#  Testing: 0.607
# Mean Squared Error: 22.749
# Mean Absolute Error: 3.856
#
# ############################## GradientBoostingRegressor evaluation: ###############################
# Accuracy:
#  Training: 0.931
#  Testing: 0.639
# Mean Squared Error: 20.898
# Mean Absolute Error: 3.632
#
# ################################## AdaBoostRegressor evaluation: ###################################
# Accuracy:
#  Training: 0.749
#  Testing: 0.583
# Mean Squared Error: 24.105
# Mean Absolute Error: 3.940
#
# ################################### LinearRegression evaluation: ###################################
# Accuracy:
#  Training: 0.692
#  Testing: 0.705
# Mean Squared Error: 17.069
# Mean Absolute Error: 3.430
#
# ######################################### SVR evaluation: ##########################################
# Accuracy:
#  Training: 0.169
#  Testing: 0.078
# Mean Squared Error: 53.314
# Mean Absolute Error: 5.883
#
# ######################################## Ridge evaluation: #########################################
# Accuracy:
#  Training: 0.689
#  Testing: 0.699
# Mean Squared Error: 17.410
# Mean Absolute Error: 3.475
#
# ######################################## Lasso evaluation: #########################################
# Accuracy:
#  Training: 0.500
#  Testing: 0.470
# Mean Squared Error: 30.660
# Mean Absolute Error: 4.284

# %%
accuracy_train = {}
reg_model_title = []

for reg_model in regression_models:
    reg_model.fit(X_train, y_train)
    y_pred_train = reg_model.predict(X_train)
    y_pred_test = reg_model.predict(X_test)
    
    accuracy_train[reg_model.__class__.__name__] = reg_model.score(X_train, y_train)
    accuracy_test = reg_model.score(X_test, y_test)
    
    # Calculating evaluation metrics
    mse = mean_squared_error(y_test, y_pred_test)
    mae = mean_absolute_error(y_test, y_pred_test)
    reg_model_title += reg_model.__class__.__name__
    
    
    print(f" {reg_model.__class__.__name__} evaluation: ".center(100, "#"))
    print(f"Accuracy:\n Training: {accuracy_train[reg_model.__class__.__name__]:.3f}\n Testing: {accuracy_test:.3f}")
    print(f"Mean Squared Error: {mse:.3f}")
    print(f"Mean Absolute Error: {mae:.3f}")
    print()
# Out:
# ################################# KNeighborsRegressor evaluation: ##################################
# Accuracy:
#  Training: 0.692
#  Testing: 0.569
# Mean Squared Error: 24.932
# Mean Absolute Error: 3.905
#
# ################################ DecisionTreeRegressor evaluation: #################################
# Accuracy:
#  Training: 1.000
#  Testing: 0.259
# Mean Squared Error: 42.846
# Mean Absolute Error: 5.369
#
# ################################ RandomForestRegressor evaluation: #################################
# Accuracy:
#  Training: 0.944
#  Testing: 0.612
# Mean Squared Error: 22.450
# Mean Absolute Error: 3.809
#
# ############################## GradientBoostingRegressor evaluation: ###############################
# Accuracy:
#  Training: 0.931
#  Testing: 0.639
# Mean Squared Error: 20.902
# Mean Absolute Error: 3.617
#
# ################################## AdaBoostRegressor evaluation: ###################################
# Accuracy:
#  Training: 0.732
#  Testing: 0.593
# Mean Squared Error: 23.554
# Mean Absolute Error: 3.925
#
# ################################### LinearRegression evaluation: ###################################
# Accuracy:
#  Training: 0.692
#  Testing: 0.705
# Mean Squared Error: 17.069
# Mean Absolute Error: 3.430
#
# ######################################### SVR evaluation: ##########################################
# Accuracy:
#  Training: 0.169
#  Testing: 0.078
# Mean Squared Error: 53.314
# Mean Absolute Error: 5.883
#
# ######################################## Ridge evaluation: #########################################
# Accuracy:
#  Training: 0.689
#  Testing: 0.699
# Mean Squared Error: 17.410
# Mean Absolute Error: 3.475
#
# ######################################## Lasso evaluation: #########################################
# Accuracy:
#  Training: 0.500
#  Testing: 0.470
# Mean Squared Error: 30.660
# Mean Absolute Error: 4.284

# %% [markdown]
# ## Visualize the model and save in visualizations folder

# %%
# Ensure the directory exists, if not create it
directory = "visualizations2"
if not os.path.exists(directory):
    os.makedirs(directory)

reg_model_titles = [reg_model.__class__.__name__ for reg_model in regression_models]

for reg_model, reg_model_title in zip(regression_models, reg_model_titles):
    reg_model.fit(X_train, y_train)
    y_pred_test = reg_model.predict(X_test)
    
    # Plotting predicted vs actual values
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred_test, color='blue', alpha=0.5)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.title(f'{reg_model_title} - Actual vs Predicted')
    
    # Save the plot as an image
    plt.savefig(os.path.join(directory, f'{reg_model_title}_plot.png'))
    
    plt.show()

print("Plots saved successfully!")
# Out:
# Plots saved successfully!

# %% [markdown]
# ----------

# %% [markdown]
# # model selection & saving

# %%
# Train the Random Forest model
random_forest2 = RandomForestRegressor()
random_forest2.fit(X_train, y_train)

# Save the trained model to a file
file_path = "model/random_forest_model2.joblib"
dump(random_forest2, file_path)
print("Random Forest model saved successfully!")
# Out:
# Random Forest model saved successfully!

# %% [markdown]
# ----------

# %% [markdown]
# # Input Model Tesing

# %%
X.head()
# Out:
#    Original  Sex  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0         1    1   23   69.97    1.72  36.2   93.1     85.2   94.5   59.0
# 1         1    1   22   78.59    1.84  38.5   93.6     83.0   98.7   58.7
# 2         1    1   22   69.85    1.68  34.0   95.8     87.9   99.2   59.6
# 3         1    1   26   83.80    1.84  37.4  101.8     86.4  101.2   60.1
# 4         1    1   24   83.58    1.81  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
# Features
feature_test = np.array([[1, 1,91, 69.9, 1.72, 36.2, 93.1, 85.2, 94.5, 59.0, 37.3, 21.9, 32.0, 27.4,17.1]])
result = random_forest2.predict(feature_test)
print(round(result[0],2))
print("==========================================================")
# Out:
# 16.76
# ==========================================================

# %%
our_data
# Out:
#      BodyFat  Original  Sex  Age   Weight  Height  Neck  Chest  Abdomen  \
# 0      12.30         1    1   23  69.9700  1.7200  36.2   93.1     85.2
# 1       6.10         1    1   22  78.5900  1.8400  38.5   93.6     83.0
# 2      25.30         1    1   22  69.8500  1.6800  34.0   95.8     87.9
# 3      10.40         1    1   26  83.8000  1.8400  37.4  101.8     86.4
# 4      28.70         1    1   24  83.5800  1.8100  34.4   97.3    100.0
# ..       ...       ...  ...  ...      ...     ...   ...    ...      ...
# 431    30.40         0    0   23  59.8752  1.5621  31.3   89.0     71.0
# 432     7.47         0    0   21  48.5352  1.5748  29.5   79.0     62.5
# 433    11.98         0    0   20  51.7104  1.5748  31.5   81.5     61.5
# 434    11.24         0    0   22  50.8032  1.6510  30.5   85.0     64.0
# 435    17.49         0    0   24  47.6280  1.6002  26.0   79.3     63.0
#
#        Hip  Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     94.5   59.0  37.3   21.9    32.0     27.4   17.1
# 1     98.7   58.7  37.3   23.4    30.5     28.9   18.2
# 2     99.2   59.6  38.9   24.0    28.8     25.2   16.6
# 3    101.2   60.1  37.3   22.8    32.4     29.4   18.2
# 4    101.9   63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...    ...   ...    ...     ...      ...    ...
# 431   98.5   56.0  36.2   21.0    28.0     24.5   16.3
# 432   89.0   49.0  33.0   20.0    25.0     22.0   15.5
# 433   90.0   49.5  32.0   19.5    27.5     22.5   15.0
# 434   88.0   45.0  32.0   19.5    24.0     21.5   15.0
# 435   86.6   46.0  33.5   19.0    24.0     21.5   14.0
#
# [420 rows x 16 columns]

# %% [markdown]
# ----------

# %% [markdown]
# # The End
